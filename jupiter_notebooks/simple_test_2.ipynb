# %%
import yfinance as yf
import pandas as pd

# List of tickers you want to combine

def get_stock_data(ticker, start="2020-01-01", end="2024-01-01"):
    df = yf.download(ticker, start=start, end=end)
    df = df[['Open', 'High', 'Low', 'Close', 'Volume']]
    df.dropna(inplace=True)
    return df


def normalize_df_zscore(data):
    data = data.copy()
    for col in ['Open', 'High', 'Low', 'Close', 'Volume']:
        mean = data[col].mean()
        std = data[col].std()
        data[col] = (data[col] - mean)/(std + 1e-8)
    data.dropna(inplace=True)
    return data

# %%
import gymnasium as gym
import numpy as np
from gymnasium import spaces
import matplotlib.pyplot as plt


class StockTradingEnv(gym.Env):
    def __init__(self, df):
        super(StockTradingEnv, self).__init__()
        self.original_df = df
        self.df= normalize_df_zscore(df)
        self.n_steps = len(self.df)
        self.current_step = 0

        #ACTIONS
        self.action_space = spaces.Discrete(3)  # 0: hold, 1: buy, 2: sell

        #OBSERVATION SPACE
        self.window_size = 14
        self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(self.window_size, self.df.shape[1]), dtype=np.float32)

        #SET VARIABLES TO CONTROL REWARDS
        self.initial_balance = 10000
        self.balance = self.initial_balance
        self.shares_held = 0
        self.net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.number_days_hold = 1



    def _next_observation(self):
        start = self.current_step - self.window_size + 1
        end = self.current_step + 1

        # Handle beginning of episode
        if start < 0:
            pad = np.zeros((abs(start), self.df.shape[1]))
            obs = np.vstack((pad, self.df.iloc[0:end].values))
        else:
            obs = self.df.iloc[start:end].values

        return obs.astype(np.float32)


    def step(self, action):
        current_price = float(self.original_df.iloc[self.current_step]["Close"])
        executed_action = 0
        if action == 1 :  # Buy
            if self.balance > 0:
                self.shares_held = self.balance / current_price
                self.balance = 0
                executed_action = 1
        elif action == 2:  # Sell
            if self.shares_held > 0:
                self.balance = self.shares_held * current_price
                self.shares_held = 0
                executed_action = 2
                self.number_days_hold = 1

        self.net_worth = self.balance + self.shares_held * current_price
        if self.shares_held > 0:
            self.number_days_hold =min(max(self.number_days_hold*(self.number_days_hold +1), 1), 100_000_000)

        reward = (self.net_worth - self.last_net_worth)*10/self.number_days_hold
        self.last_net_worth = self.net_worth
        self.net_worths.append(self.net_worth)
        self.actions.append(executed_action)

        self.current_step += 1
        terminated = self.current_step >= len(self.df) - 1
        truncated = False  # Or set appropriate truncation logic

        return self._next_observation(), reward, terminated, truncated, {
            "net_worth": self.net_worth,
            "shares_held": self.shares_held,
            "balance": self.balance,
            "actions": self.actions,
        }



    def reset(self, *, seed=None, options=None):
        super().reset(seed=seed)
        self.current_step = self.window_size - 1
        self.balance = self.initial_balance
        self.shares_held = 0
        self.net_worth = self.initial_balance
        self.max_net_worth = self.initial_balance
        self.last_net_worth = self.initial_balance
        self.net_worths = []
        self.actions = []
        return self._next_observation(), {}


    def render(self, mode='human'):
        if not hasattr(self, "net_worths") or len(self.net_worths) == 0:
            print("No data to render yet.")
            return

        prices = self.original_df['Close'].iloc[self.window_size:self.window_size+len(self.net_worths)].reset_index(drop=True)
        plt.figure(figsize=(12, 6))

        # Plot net worth
        plt.plot(self.net_worths, label='Net Worth', color='blue')

        # Optional: show buy/sell points
        for i, action in enumerate(self.actions):
            if action == 1:  # Buy
                plt.scatter(i, self.net_worths[i], marker='^', color='green')
            elif action == 2:  # Sell
                plt.scatter(i, self.net_worths[i], marker='v', color='red')
            elif action == 0:
                plt.scatter(i, self.net_worths[i], marker='o', color='black')

        plt.title("Net Worth Over Time")
        plt.xlabel("Time Step")
        plt.ylabel("Net Worth")
        plt.legend()
        plt.grid()
        plt.tight_layout()
        plt.show()

# %%
tickers = ["AAPL", "GOOG", "TSLA", "AMZN", "MSFT"]
start = "2020-01-01"
end = "2024-01-01"
dfs = [get_stock_data(ticker, start, end) for ticker in tickers]
common_index = set(dfs[0].index)
for df in dfs[1:]:
    common_index = common_index & set(df.index)
common_index = sorted(list(common_index))
aligned_dfs = [df.loc[common_index].copy() for df in dfs]

# -- Prepare one environment per ticker for DummyVecEnv
def make_env(df):
    #norm_df = normalize_df_zscore(df)
    return lambda: StockTradingEnv(df)

env_fns = [make_env(df) for df in aligned_dfs]
vec_env = DummyVecEnv(env_fns)

model = PPO("MlpPolicy", vec_env, verbose=1)
model.learn(total_timesteps=500_000)
model.save("models/ppo_multiasset_trader")

# -- Inference: predictions per ticker in parallel
obs = vec_env.reset()
terminated = [False] * len(tickers)
truncated = [False] * len(tickers)
while not all(terminated) and not all(truncated):
    actions, _ = model.predict(obs, deterministic=True)
    step_result = vec_env.step(actions)
    if len(step_result) == 5:
        obs, rewards, term, trunc, infos = step_result
        terminated = [a or b for a, b in zip(terminated, term)]
        truncated = [a or b for a, b in zip(truncated, trunc)]
    elif len(step_result) == 4:
        obs, rewards, done, infos = step_result
        terminated = [a or b for a, b in zip(terminated, done)]
        truncated = [False] * len(done)  # Mark as not truncated, or adjust as needed
    else:
        raise RuntimeError("Unexpected number of values returned by vec_env.step()")
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# /var/folders/rf/wm_j98lj3pz_hzy5g_tc1mmr0000gn/T/ipykernel_35405/2226480084.py:48: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(self.original_df.iloc[self.current_step]["Close"])
# Using cpu device
# ------------------------------
# | time/              |       |
# |    fps             | 4464  |
# |    iterations      | 1     |
# |    time_elapsed    | 2     |
# |    total_timesteps | 10240 |
# ------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 3085          |
# |    iterations           | 2             |
# |    time_elapsed         | 6             |
# |    total_timesteps      | 20480         |
# | train/                  |               |
# |    approx_kl            | 0.00089211634 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 1.57e-05      |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+07      |
# |    n_updates            | 10            |
# |    policy_gradient_loss | -0.000753     |
# |    value_loss           | 3.86e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2767          |
# |    iterations           | 3             |
# |    time_elapsed         | 11            |
# |    total_timesteps      | 30720         |
# | train/                  |               |
# |    approx_kl            | 0.00070751767 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00117       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.1e+07       |
# |    n_updates            | 20            |
# |    policy_gradient_loss | -0.000234     |
# |    value_loss           | 3.64e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2650         |
# |    iterations           | 4            |
# |    time_elapsed         | 15           |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.0010075073 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00236      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.41e+07     |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.000387    |
# |    value_loss           | 2.24e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2585         |
# |    iterations           | 5            |
# |    time_elapsed         | 19           |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0006425803 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0019       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.92e+07     |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.000502    |
# |    value_loss           | 2.35e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2542          |
# |    iterations           | 6             |
# |    time_elapsed         | 24            |
# |    total_timesteps      | 61440         |
# | train/                  |               |
# |    approx_kl            | 0.00028876835 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00266       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.66e+07      |
# |    n_updates            | 50            |
# |    policy_gradient_loss | -0.00029      |
# |    value_loss           | 4.05e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2499         |
# |    iterations           | 7            |
# |    time_elapsed         | 28           |
# |    total_timesteps      | 71680        |
# | train/                  |              |
# |    approx_kl            | 0.0006331437 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00351      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.77e+07     |
# |    n_updates            | 60           |
# |    policy_gradient_loss | -0.000358    |
# |    value_loss           | 2.96e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2240         |
# |    iterations           | 8            |
# |    time_elapsed         | 36           |
# |    total_timesteps      | 81920        |
# | train/                  |              |
# |    approx_kl            | 0.0001872066 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00195      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.22e+07     |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.000205    |
# |    value_loss           | 4.27e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2197          |
# |    iterations           | 9             |
# |    time_elapsed         | 41            |
# |    total_timesteps      | 92160         |
# | train/                  |               |
# |    approx_kl            | 0.00011425179 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00278       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.51e+06      |
# |    n_updates            | 80            |
# |    policy_gradient_loss | -0.000163     |
# |    value_loss           | 4.78e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2190          |
# |    iterations           | 10            |
# |    time_elapsed         | 46            |
# |    total_timesteps      | 102400        |
# | train/                  |               |
# |    approx_kl            | 3.6632886e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00307       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.27e+07      |
# |    n_updates            | 90            |
# |    policy_gradient_loss | -7.86e-05     |
# |    value_loss           | 8.36e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2185          |
# |    iterations           | 11            |
# |    time_elapsed         | 51            |
# |    total_timesteps      | 112640        |
# | train/                  |               |
# |    approx_kl            | 1.4123245e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00295       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.25e+07      |
# |    n_updates            | 100           |
# |    policy_gradient_loss | -4.95e-05     |
# |    value_loss           | 6.79e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2190         |
# |    iterations           | 12           |
# |    time_elapsed         | 56           |
# |    total_timesteps      | 122880       |
# | train/                  |              |
# |    approx_kl            | 7.455483e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00491      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.33e+07     |
# |    n_updates            | 110          |
# |    policy_gradient_loss | -3.71e-05    |
# |    value_loss           | 1e+08        |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2190          |
# |    iterations           | 13            |
# |    time_elapsed         | 60            |
# |    total_timesteps      | 133120        |
# | train/                  |               |
# |    approx_kl            | 4.7073896e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00464       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.32e+07      |
# |    n_updates            | 120           |
# |    policy_gradient_loss | -8.45e-05     |
# |    value_loss           | 5.67e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2175          |
# |    iterations           | 14            |
# |    time_elapsed         | 65            |
# |    total_timesteps      | 143360        |
# | train/                  |               |
# |    approx_kl            | 2.9662274e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.01          |
# |    learning_rate        | 0.0003        |
# |    loss                 | 9.8e+06       |
# |    n_updates            | 130           |
# |    policy_gradient_loss | -3.27e-05     |
# |    value_loss           | 2.54e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2166         |
# |    iterations           | 15           |
# |    time_elapsed         | 70           |
# |    total_timesteps      | 153600       |
# | train/                  |              |
# |    approx_kl            | 1.576576e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0138       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.47e+07     |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -7.04e-05    |
# |    value_loss           | 2.88e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2159         |
# |    iterations           | 16           |
# |    time_elapsed         | 75           |
# |    total_timesteps      | 163840       |
# | train/                  |              |
# |    approx_kl            | 2.876151e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00403      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.26e+07     |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -1.51e-05    |
# |    value_loss           | 1.12e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2162         |
# |    iterations           | 17           |
# |    time_elapsed         | 80           |
# |    total_timesteps      | 174080       |
# | train/                  |              |
# |    approx_kl            | 7.568975e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00551      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.14e+07     |
# |    n_updates            | 160          |
# |    policy_gradient_loss | -1.71e-05    |
# |    value_loss           | 5.21e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2157          |
# |    iterations           | 18            |
# |    time_elapsed         | 85            |
# |    total_timesteps      | 184320        |
# | train/                  |               |
# |    approx_kl            | 7.4169367e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00669       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.91e+07      |
# |    n_updates            | 170           |
# |    policy_gradient_loss | -3.64e-06     |
# |    value_loss           | 4e+07         |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2163         |
# |    iterations           | 19           |
# |    time_elapsed         | 89           |
# |    total_timesteps      | 194560       |
# | train/                  |              |
# |    approx_kl            | 9.773823e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.00657      |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.67e+07     |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -1.54e-05    |
# |    value_loss           | 4.06e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2169          |
# |    iterations           | 20            |
# |    time_elapsed         | 94            |
# |    total_timesteps      | 204800        |
# | train/                  |               |
# |    approx_kl            | 5.1485376e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00726       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.18e+07      |
# |    n_updates            | 190           |
# |    policy_gradient_loss | -1.39e-05     |
# |    value_loss           | 4.44e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2177          |
# |    iterations           | 21            |
# |    time_elapsed         | 98            |
# |    total_timesteps      | 215040        |
# | train/                  |               |
# |    approx_kl            | 1.2944557e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0158        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.52e+07      |
# |    n_updates            | 200           |
# |    policy_gradient_loss | -6.96e-05     |
# |    value_loss           | 4.62e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2091          |
# |    iterations           | 22            |
# |    time_elapsed         | 107           |
# |    total_timesteps      | 225280        |
# | train/                  |               |
# |    approx_kl            | 2.7826755e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0129        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.42e+07      |
# |    n_updates            | 210           |
# |    policy_gradient_loss | -1.17e-05     |
# |    value_loss           | 5.56e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2007         |
# |    iterations           | 23           |
# |    time_elapsed         | 117          |
# |    total_timesteps      | 235520       |
# | train/                  |              |
# |    approx_kl            | 1.814617e-05 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0193       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.16e+07     |
# |    n_updates            | 220          |
# |    policy_gradient_loss | -7.98e-05    |
# |    value_loss           | 4.15e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2018         |
# |    iterations           | 24           |
# |    time_elapsed         | 121          |
# |    total_timesteps      | 245760       |
# | train/                  |              |
# |    approx_kl            | 3.304804e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0182       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.34e+07     |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -2.22e-05    |
# |    value_loss           | 4.02e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2021         |
# |    iterations           | 25           |
# |    time_elapsed         | 126          |
# |    total_timesteps      | 256000       |
# | train/                  |              |
# |    approx_kl            | 9.722775e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0109       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 8.64e+06     |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -8.96e-06    |
# |    value_loss           | 2.84e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2028          |
# |    iterations           | 26            |
# |    time_elapsed         | 131           |
# |    total_timesteps      | 266240        |
# | train/                  |               |
# |    approx_kl            | 5.1302313e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0124        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.53e+07      |
# |    n_updates            | 250           |
# |    policy_gradient_loss | -3.4e-05      |
# |    value_loss           | 3.75e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2034          |
# |    iterations           | 27            |
# |    time_elapsed         | 135           |
# |    total_timesteps      | 276480        |
# | train/                  |               |
# |    approx_kl            | 3.3147518e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00449       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 4.25e+07      |
# |    n_updates            | 260           |
# |    policy_gradient_loss | -6.24e-06     |
# |    value_loss           | 7.33e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2042          |
# |    iterations           | 28            |
# |    time_elapsed         | 140           |
# |    total_timesteps      | 286720        |
# | train/                  |               |
# |    approx_kl            | 2.1586427e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.00758       |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.37e+07      |
# |    n_updates            | 270           |
# |    policy_gradient_loss | -1.72e-05     |
# |    value_loss           | 5.92e+07      |
# -------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 2051        |
# |    iterations           | 29          |
# |    time_elapsed         | 144         |
# |    total_timesteps      | 296960      |
# | train/                  |             |
# |    approx_kl            | 8.70935e-06 |
# |    clip_fraction        | 0           |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -1.1        |
# |    explained_variance   | 0.0159      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.25e+07    |
# |    n_updates            | 280         |
# |    policy_gradient_loss | -3.59e-05   |
# |    value_loss           | 5.38e+07    |
# -----------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2058          |
# |    iterations           | 30            |
# |    time_elapsed         | 149           |
# |    total_timesteps      | 307200        |
# | train/                  |               |
# |    approx_kl            | 2.1826156e-05 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0208        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.39e+07      |
# |    n_updates            | 290           |
# |    policy_gradient_loss | -0.000149     |
# |    value_loss           | 5.31e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2066         |
# |    iterations           | 31           |
# |    time_elapsed         | 153          |
# |    total_timesteps      | 317440       |
# | train/                  |              |
# |    approx_kl            | 4.008878e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0268       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 2.04e+07     |
# |    n_updates            | 300          |
# |    policy_gradient_loss | -4.74e-06    |
# |    value_loss           | 2.52e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2074          |
# |    iterations           | 32            |
# |    time_elapsed         | 157           |
# |    total_timesteps      | 327680        |
# | train/                  |               |
# |    approx_kl            | 1.5414611e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0164        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.78e+07      |
# |    n_updates            | 310           |
# |    policy_gradient_loss | -8.31e-06     |
# |    value_loss           | 5.49e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2083          |
# |    iterations           | 33            |
# |    time_elapsed         | 162           |
# |    total_timesteps      | 337920        |
# | train/                  |               |
# |    approx_kl            | 1.3580371e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0242        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 3.22e+07      |
# |    n_updates            | 320           |
# |    policy_gradient_loss | -9.06e-06     |
# |    value_loss           | 5.73e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2084          |
# |    iterations           | 34            |
# |    time_elapsed         | 167           |
# |    total_timesteps      | 348160        |
# | train/                  |               |
# |    approx_kl            | 4.6177882e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0411        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 5.3e+06       |
# |    n_updates            | 330           |
# |    policy_gradient_loss | -1.34e-05     |
# |    value_loss           | 1.9e+07       |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2085          |
# |    iterations           | 35            |
# |    time_elapsed         | 171           |
# |    total_timesteps      | 358400        |
# | train/                  |               |
# |    approx_kl            | 2.0180305e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0207        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.13e+07      |
# |    n_updates            | 340           |
# |    policy_gradient_loss | -1.92e-05     |
# |    value_loss           | 2.49e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2092          |
# |    iterations           | 36            |
# |    time_elapsed         | 176           |
# |    total_timesteps      | 368640        |
# | train/                  |               |
# |    approx_kl            | 4.3057952e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0284        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.6e+06       |
# |    n_updates            | 350           |
# |    policy_gradient_loss | -7.09e-06     |
# |    value_loss           | 2.77e+07      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2098         |
# |    iterations           | 37           |
# |    time_elapsed         | 180          |
# |    total_timesteps      | 378880       |
# | train/                  |              |
# |    approx_kl            | 2.615439e-06 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0246       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 9.72e+06     |
# |    n_updates            | 360          |
# |    policy_gradient_loss | -2.88e-05    |
# |    value_loss           | 3.27e+07     |
# ------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2103           |
# |    iterations           | 38             |
# |    time_elapsed         | 184            |
# |    total_timesteps      | 389120         |
# | train/                  |                |
# |    approx_kl            | 1.11683036e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.1           |
# |    explained_variance   | 0.0093         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 5.49e+07       |
# |    n_updates            | 370            |
# |    policy_gradient_loss | -2.84e-06      |
# |    value_loss           | 9.6e+07        |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2109          |
# |    iterations           | 39            |
# |    time_elapsed         | 189           |
# |    total_timesteps      | 399360        |
# | train/                  |               |
# |    approx_kl            | 1.0491116e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0164        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.12e+07      |
# |    n_updates            | 380           |
# |    policy_gradient_loss | -1.35e-05     |
# |    value_loss           | 2.85e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2114          |
# |    iterations           | 40            |
# |    time_elapsed         | 193           |
# |    total_timesteps      | 409600        |
# | train/                  |               |
# |    approx_kl            | 1.1642696e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0223        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 6.4e+06       |
# |    n_updates            | 390           |
# |    policy_gradient_loss | -6.75e-06     |
# |    value_loss           | 2.14e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2119          |
# |    iterations           | 41            |
# |    time_elapsed         | 198           |
# |    total_timesteps      | 419840        |
# | train/                  |               |
# |    approx_kl            | 4.6569622e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0217        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 2.35e+07      |
# |    n_updates            | 400           |
# |    policy_gradient_loss | -8.16e-06     |
# |    value_loss           | 4.89e+07      |
# -------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2122          |
# |    iterations           | 42            |
# |    time_elapsed         | 202           |
# |    total_timesteps      | 430080        |
# | train/                  |               |
# |    approx_kl            | 6.2581967e-07 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0225        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.05e+07      |
# |    n_updates            | 410           |
# |    policy_gradient_loss | -9.68e-06     |
# |    value_loss           | 4.15e+07      |
# -------------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 2127           |
# |    iterations           | 43             |
# |    time_elapsed         | 206            |
# |    total_timesteps      | 440320         |
# | train/                  |                |
# |    approx_kl            | 1.14744765e-07 |
# |    clip_fraction        | 0              |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -1.1           |
# |    explained_variance   | 0.0166         |
# |    learning_rate        | 0.0003         |
# |    loss                 | 3.33e+07       |
# |    n_updates            | 420            |
# |    policy_gradient_loss | -5.33e-06      |
# |    value_loss           | 2.85e+07       |
# --------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2131          |
# |    iterations           | 44            |
# |    time_elapsed         | 211           |
# |    total_timesteps      | 450560        |
# | train/                  |               |
# |    approx_kl            | 1.0884658e-06 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.014         |
# |    learning_rate        | 0.0003        |
# |    loss                 | 8.52e+07      |
# |    n_updates            | 430           |
# |    policy_gradient_loss | -1.65e-05     |
# |    value_loss           | 1.28e+08      |
# -------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2134         |
# |    iterations           | 45           |
# |    time_elapsed         | 215          |
# |    total_timesteps      | 460800       |
# | train/                  |              |
# |    approx_kl            | 9.934708e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0214       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.08e+07     |
# |    n_updates            | 440          |
# |    policy_gradient_loss | -6.85e-06    |
# |    value_loss           | 7.52e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2137         |
# |    iterations           | 46           |
# |    time_elapsed         | 220          |
# |    total_timesteps      | 471040       |
# | train/                  |              |
# |    approx_kl            | 7.543655e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0676       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 1.3e+07      |
# |    n_updates            | 450          |
# |    policy_gradient_loss | -8.37e-06    |
# |    value_loss           | 3.56e+07     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2142         |
# |    iterations           | 47           |
# |    time_elapsed         | 224          |
# |    total_timesteps      | 481280       |
# | train/                  |              |
# |    approx_kl            | 2.401066e-08 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0147       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 6.69e+07     |
# |    n_updates            | 460          |
# |    policy_gradient_loss | -1.72e-06    |
# |    value_loss           | 1.24e+08     |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 2146         |
# |    iterations           | 48           |
# |    time_elapsed         | 229          |
# |    total_timesteps      | 491520       |
# | train/                  |              |
# |    approx_kl            | 2.618646e-07 |
# |    clip_fraction        | 0            |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -1.1         |
# |    explained_variance   | 0.0169       |
# |    learning_rate        | 0.0003       |
# |    loss                 | 3.94e+07     |
# |    n_updates            | 470          |
# |    policy_gradient_loss | -4.78e-06    |
# |    value_loss           | 4.66e+07     |
# ------------------------------------------
# -------------------------------------------
# | time/                   |               |
# |    fps                  | 2150          |
# |    iterations           | 49            |
# |    time_elapsed         | 233           |
# |    total_timesteps      | 501760        |
# | train/                  |               |
# |    approx_kl            | 5.5017882e-08 |
# |    clip_fraction        | 0             |
# |    clip_range           | 0.2           |
# |    entropy_loss         | -1.1          |
# |    explained_variance   | 0.0119        |
# |    learning_rate        | 0.0003        |
# |    loss                 | 1.9e+08       |
# |    n_updates            | 480           |
# |    policy_gradient_loss | -1.52e-06     |
# |    value_loss           | 1.63e+08      |
# -------------------------------------------

# %%
## Take the last 50 rows

partial_df = get_stock_data(ticker="AAPL", start="2024-01-01", end="2025-05-30")


env = StockTradingEnv(partial_df)
obs , _ = env.reset()

terminated = False
truncated = False

while not truncated and not terminated :
    action, _ = model.predict(obs, deterministic=True)
    obs, _, terminated, truncated, results = env.step(action)


env.render()
# Out:
# [*********************100%***********************]  1 of 1 completed
# /var/folders/rf/wm_j98lj3pz_hzy5g_tc1mmr0000gn/T/ipykernel_35405/2226480084.py:48: FutureWarning: Calling float on a single element Series is deprecated and will raise a TypeError in the future. Use float(ser.iloc[0]) instead
#   current_price = float(self.original_df.iloc[self.current_step]["Close"])

# %%
import numpy as np

actions = results['actions']  # assuming this is a list or 1D array of integers 0, 1, 2
actions_array = np.array(actions)
counts = np.bincount(actions_array, minlength=3)  # Creates counts for 0, 1, 2

num_zeros = counts[0]
num_ones = counts[1]
num_twos = counts[2]

print(f"Number of action 0 (hold): {num_zeros}")
print(f"Number of action 1 (buy): {num_ones}")
print(f"Number of action 2 (sell): {num_twos}")
# Out:
# Number of action 0 (hold): 62
# Number of action 1 (buy): 6
# Number of action 2 (sell): 6
